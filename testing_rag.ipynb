# %%
# --- Cell A: wire Search + Azure OpenAI into a tiny RAG helper ---

import os, textwrap
from typing import List, Dict, Optional

from dotenv import load_dotenv, find_dotenv
from azure.identity import DefaultAzureCredential
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.models import VectorizableTextQuery
from azure.core.exceptions import HttpResponseError
from azure.search.documents.models import HybridSearch

from openai import AzureOpenAI, APIConnectionError

load_dotenv(find_dotenv(), override=True)

# ---- Config (expects the same envs you already used) ----
SEARCH_ENDPOINT = os.environ["AZURE_SEARCH_ENDPOINT"]
SEARCH_INDEX    = os.environ["AZURE_SEARCH_INDEX"]
SEARCH_KEY      = os.getenv("AZURE_SEARCH_API_KEY")  # omit if using AAD/RBAC
VECTOR_FIELD    = os.getenv("VECTOR_FIELD", "text_vector_v4")
TEXT_FIELD      = os.getenv("TEXT_FIELD", "chunk")

AOAI_ENDPOINT   = os.environ["AZURE_OPENAI_ENDPOINT"]            # https://<resource>.openai.azure.com
AOAI_API_VER    = os.environ.get("AZURE_OPENAI_API_VERSION", "2024-10-21")
AOAI_DEPLOYMENT = os.environ["AZURE_OPENAI_DEPLOYMENT"]          # e.g., gpt-4o-mini / o3-mini / gpt-5 preview
AOAI_KEY        = os.getenv("AZURE_OPENAI_API_KEY")              # omit if using AAD

# ---- Clients ----
def get_search_client() -> SearchClient:
    cred = AzureKeyCredential(SEARCH_KEY) if SEARCH_KEY else DefaultAzureCredential()
    return SearchClient(SEARCH_ENDPOINT, SEARCH_INDEX, credential=cred)

def get_aoai_client() -> AzureOpenAI:
    if AOAI_KEY:
        return AzureOpenAI(azure_endpoint=AOAI_ENDPOINT, api_key=AOAI_KEY, api_version=AOAI_API_VER)
    return AzureOpenAI(azure_endpoint=AOAI_ENDPOINT, azure_ad_token_provider=DefaultAzureCredential().get_token, api_version=AOAI_API_VER)

# %% [markdown]
# # Lab 1 - RAG Opt

# %%
def retrieve_hybrid_enhanced(query: str, top: int = 20, k: int = 50, max_text_recall_size:int = 200):
    sc = get_search_client()
    try:
        vq = VectorizableTextQuery(
            text=query, 
            k=k, 
            fields=VECTOR_FIELD, 
            weight=1.8
            )
        
        # Prefer vector-only search (integrated vectorization). If your index isn't set up for it, this raises.
        results = sc.search(
            search_text=query, 
            vector_queries=[vq],
            top=top, 
            query_type="semantic",
            query_caption="extractive", 
            query_answer='extractive',
            hybrid_search=HybridSearch(max_text_recall_size=max_text_recall_size),
            query_caption_highlight_enabled=True,
            semantic_error_mode="partial"
            )
        mode = "hybrid + semantic"
    except HttpResponseError as e:
        # Fall back to lexical so you still get results while fixing vector config
        results = sc.search(search_text=query, top=k)
        mode = f"lexical (fallback due to: {e.__class__.__name__})"

    hits: List[Dict] = []
    for r in results:
        d = r.copy() if hasattr(r, "copy") else {k2: r[k2] for k2 in r}
        d["score"] = d.get("@search.reranker_score") or d.get("@search.score") or 0.0
        caps = d.get("@search.captions")
        if isinstance(caps, list) and caps:
            d["caption"] = getattr(caps[0], "text", None)
        hits.append(d)

    return mode, hits

# %%
def build_context(hits: List[Dict], text_field: str = TEXT_FIELD, max_chars: int = 20000) -> str:
    """Build a compact, numbered context block to feed the model."""
    lines = []
    total = 0
    for i, h in enumerate(hits, 1):
        title     = h.get("title")
        chunk_id  = h.get("chunk_id")
        snippet   = (h.get(text_field) or "")
        if not snippet:
            continue
        snippet = textwrap.shorten(snippet, width=700, placeholder=" ...")
        block = f"[{i}] title={title!r} | chunk_id={chunk_id} | score={h.get('score'):.4f}\n{snippet}"
        if total + len(block) > max_chars:
            break
        total += len(block)
        lines.append(block)
    return "\n\n---\n\n".join(lines)

# %%
from prompts import new_system_finance_prompt
from prompts2 import section1, section2, section3, section4, section5, section6, section7, section8

def rag_answer(question: str):
    
    client = get_aoai_client()

    question = f"Create the analysis of this company profile section for Radley + Co. Limited."

    replies =[]
    # Starting loop for section
    sections = [section1, section2, section3, section4, section5, section6, section7, section8]
    
    

    for section in sections:

        mode, hits = retrieve_hybrid_enhanced(section)
        ctx = build_context(hits) 
        
        system_msg = section
        user_msg = f"Question:\n{question}\n\n Context snippets (numbered):\n{ctx}"

        messages = [
            {"role": "system", "content": system_msg},
            {"role": "user",   "content": user_msg},
        ]

        # Try streaming first (SSE). Some networks/proxies block streaming; if so, fall back.
        try:
            text = ""
            stream = client.chat.completions.create(
                model=AOAI_DEPLOYMENT,
                messages=messages,
                stream=True,
                stream_options={"include_usage": True},
            )
            for chunk in stream:
                choices = getattr(chunk, "choices", None)
                if not choices:
                    continue
                delta = getattr(choices[0], "delta", None)
                if not delta:
                    continue
                piece = getattr(delta, "content", None)
                if piece:
                    text += piece
            answer = text if text else "(no text returned)"
            mode_model = "streaming"
        except APIConnectionError:
            resp = client.chat.completions.create(
                model=AOAI_DEPLOYMENT,
                messages=messages,
            )
            answer = resp.choices[0].message.content
            mode_model = "non-streaming (fallback)"

        replies.append(
            {
                "search_mode": mode,
                "model_mode": mode_model,
                "answer": answer,
                "sources": [
                    {"n": i+1, "title": h.get("title"), "chunk_id": h.get("chunk_id"), "score": h.get("score")}
                    for i, h in enumerate(hits)
                ],
            }
        )
    
    return replies

# %%
answer = rag_answer(question="Create the company profile of Radley + Co. Limited.")
# Out:
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored

# %%
for a in answer:
    print(a['answer'])
# Out:
# Company Snapshot — Radley + Co. Limited (Introduction Table)
#
# - Primary Industry: n/a
# - Incorporation Year: n/a
# - Headquarters (city, country): n/a
# - Number of Employees: 450 (average monthly, FY24)
# - Operational KPIs: n/a
#
# Sources:
# - Radley + Co. Limited Annual Report, FY24 – Strategic Report (Average monthly number of employees 450 for the 52 weeks ended 27 Apr-24) [2024_radley.pdf, p.4]
# - Radley + Co. Limited Annual Reports FY23 and FY22 reviewed; the available sections provided did not disclose the principal activity/industry label, incorporation year, headquarters or specific operational KPIs beyond staff numbers [2023_radley.pdf; 2022_radley.pdf]
# 2. Business Overview
# - Radley + Co. Limited operates in the retail sector and is exposed to the retail markets in the U.K. and the U.S.A., where consumer disposable income dynamics are an important driver of trading performance.
# - The company’s trading plan assumes no like-for-like growth but incorporates moderate growth from opening new sales channels, with management noting the recovery of some one-off operational disruptions from the prior year.
# - It manages key financial risks arising from exchange rates, credit and liquidity through a risk management programme that monitors currency exposure and related finance costs, and it uses forward currency contracts when necessary.
# - The company’s customers are end consumers whose demand is sensitive to cost of living pressures, including higher food, fuel and interest costs that weigh on disposable income.
# - The company is facing financial stress with Group turnover declining to £72.0m in FY24, EBITDA before non-recurring items decreasing to £2.7m and net debt increasing to £10.8m, alongside an FY24 operating loss of £0.5m, and the Directors flagged a material uncertainty over going concern given that debt covenants could be breached in a downside case and additional financing may be required.
#
# Sources:
# - Radley + Co. Limited Annual Report and Financial Statements FY24 (Strategic Report, KPIs, Going Concern) – 52 weeks ended 27 Apr-24, pp. 4, 7, 17, 41
# - Radley + Co. Limited Annual Report and Financial Statements FY23 (Strategic Report, Going Concern) – 53 weeks ended 29 Apr-23, p. 30
# - Radley + Co. Limited Annual Report and Financial Statements FY22 (Strategic Report, Financial risk management) – 52 weeks ended 23 Apr-22, pp. 11–12
# 3. Revenue Split
#
# Latest year used: FY24 (52 weeks ended 27-Apr-24). Total revenue: £71.975m
#
# Revenue split by geography (FY24)
# - United Kingdom: £52.832m (73.39%)
# - EMEA (ex-UK): £0.494m (0.69%)
# - North America: £16.590m (23.05%)
# - Asia Pacific: £2.059m (2.86%)
# - Total: £71.975m (100.00%)
# Note: Percentages may not sum to exactly 100% due to rounding.
#
# Revenue split by category (FY24)
# - Sales of goods: £70.593m (98.18%)
# - Royalty income: £1.382m (1.92%)
# - Total: £71.975m (100.10%)
# Note: Percentages may not sum to exactly 100% due to rounding.
#
# Source: Radley + Co. Limited Annual Report FY24, Note 3: Turnover (geographical and category breakdown) [2024_radley.pdf, p.55]
# 4a. Products/Services Overview
# - Retail of bags and accessories: The group conducts retail of bags and accessories through its UK retail subsidiary (Radley Retail Limited), whose stated principal activity is “Retail of bags and accessories.” [Source: FY23 Radley + Co. Limited, Notes to the Financial Statements – Subsidiary undertakings (registered office/principal activity), page showing Radley Retail Limited; 2023_radley.pdf, p. 52 (context id 34)]
# - Sale of branded goods: The group’s revenue is predominantly from sales of goods under the Radley brand. Sales of goods were reported as £76.0m in FY23 and £70.6m in FY24. [Source: FY23 Notes – Turnover analysis by category; 2023_radley.pdf, p. 42 (context id 24). FY24 Notes – Turnover analysis by category; 2024_radley.pdf, p. 55 (context id 29)]
# - Brand licensing/royalty income: The group earns royalty income from licensing arrangements for the Radley brand (reported as £1.27m in FY23 and £1.38m in FY24). [Source: FY23 Notes – Turnover analysis by category; 2023_radley.pdf, p. 42 (context id 24). FY24 Notes – Turnover analysis by category; 2024_radley.pdf, p. 55 (context id 29)]
#
# Note: Beyond the high-level categories above (bags and accessories; licensed brand categories), the latest annual reports/financial statements do not provide a more granular list of specific product lines; further detail was not available in the filed accounts reviewed. [Source: FY23/FY24 Radley + Co. Limited Annual Reports; 2023_radley.pdf, p. 42 (context id 24); 2024_radley.pdf, p. 55 (context id 29)]
#
#
# 4b. Geographical Footprint
# The company’s filings disclose legal entity registered offices and indicate UK retail operations. A summary of countries with identified facilities/registered offices is below.
#
# | Country | Facility type(s) | Details/Entity |
# | United Kingdom | Registered office/operating office; Retail stores | Radley Retail Limited registered office at Unit 1B, Etheridge Avenue, Brinklow, Milton Keynes MK10 0BP; multiple UK retail stores are implied by store closure and onerous lease provisions noted in FY24. [Sources: FY23 Notes – Subsidiary undertakings; 2023_radley.pdf, p. 52 (context id 34). FY24 Notes – Non‑recurring items (store closures/onerous leases); 2024_radley.pdf, p. 56 (context id 30)] |
# | Hong Kong (SAR) | Registered office (non‑trading subsidiary) | Radley Hong Kong Limited (non‑trading), registered office: Unit 2212, 22/F, HongKong Plaza, 188 Connaught Road West, Sai Wan, Hong Kong. [Source: FY23 Notes – Subsidiary undertakings; 2023_radley.pdf, p. 52 (context id 34)] |
# | China (Mainland) | Registered office/office (subsidiary) | Radley China Limited, registered office disclosed in filings in Shanghai (address shown in accounts). [Source: FY23 Notes – Subsidiary undertakings; 2023_radley.pdf, p. 52 (context id 34)] |
#
# Additional notes:
# - Japan: The group previously operated in Japan (Radley Japan K.K.), but received a credit on closure and has since exited; no current Japan facilities are indicated. [Source: FY23 Notes – Non‑recurring items (credit for closure of Radley Japan K.K.); 2023_radley.pdf, p. 43 (context id 25)]
# - North America/EMEA/APAC sales: The group reports sales by destination in these regions (e.g., UK, North America, EMEA, Asia Pacific), but the annual reports do not disclose offices, warehouses, or manufacturing facilities in those regions beyond the entities listed above. [Sources: FY23 Notes – Turnover by destination; 2023_radley.pdf, p. 42 (context id 24). FY24 Notes – Turnover by destination; 2024_radley.pdf, p. 55 (context id 29)]
# - Manufacturing: The financial statements do not disclose owned manufacturing facilities; no manufacturing locations are identified in the filings reviewed. [Source: FY23/FY24 Radley + Co. Limited Annual Reports; 2023_radley.pdf, p. 42 (context id 24); 2024_radley.pdf, p. 55 (context id 29)]
# 5. Key Recent Developments
#
# - Aug-24: Radley + Co. Limited liquidated a wholly owned dormant subsidiary after the FY24 year-end, with the directors noting no other post balance sheet events. Source: 2024 Annual Report, Directors’ Report (2024_radley.pdf, p.19)
#
# - May-24: Radley + Co. Limited approved FY24 results for the 52 weeks ended 27 Apr 2024, reporting turnover of £72.0m, an operating loss of £0.5m, EBITDA before non-recurring items of £2.7m, and net debt of £10.8m. Sources: 2024 Annual Report, Strategic Report KPIs (2024_radley.pdf, p.4); Note 3 – Turnover by geography (2024_radley.pdf, p.55)
#
# - May-24: Radley + Co. Limited highlighted persistent consumer disposable income pressures and higher interest rates in its going concern assessment and confirmed it has adequate resources for at least 12 months from the approval date. Source: 2024 Annual Report, Going Concern (2024_radley.pdf, p.14)
#
# - May-24: Radley + Co. Limited reported an increase in the provision for impairment of trade receivables to £0.5m from £0.1m year-on-year. Source: 2024 Annual Report, Note 17 – Debtors (2024_radley.pdf, p.63)
#
# - Apr-23: Radley + Co. Limited recorded non-recurring items including £0.6m of severance costs and £0.1m of legal fees associated with legal entity rationalisation, recognized a fair value loss on foreign exchange forward contracts, and booked a credit relating to the closure of Radley Japan K.K. Source: 2023 Annual Report, Note 5 – Non-recurring items (2023_radley.pdf, p.43)
#
# - Apr-23: Radley + Co. Limited saw amounts owed to group undertakings within current liabilities rise to £24.4m from £5.0m in the prior year, with interest on loan agreements accruing at 5% per annum. Source: 2023 Annual Report, Note 17 – Creditors due within one year (2023_radley.pdf, p.54)
#
# - Jan-23: Radley + Co. Limited filed FY22 results highlighting impairments of £0.42m against intercompany balances with Radley China Limited and £0.06m with Radley Hong Kong Limited, reflecting ongoing rationalisation of overseas legal entities. Source: 2022 Annual Report, Note 5 – Non-recurring items (2022_radley.pdf, p.50)
#
# - Jan-23: Radley + Co. Limited disclosed in its FY22 going concern assessment that a 20% sales decline would, absent mitigation, reduce asset-based facility headroom below the minimum requirement of 15% of net collateral by Oct-23, with planned reductions in marketing, discretionary costs and capex to preserve liquidity. Source: 2022 Annual Report, Going Concern scenario analysis (2022_radley.pdf, p.18)
#
# - Jan-23: Radley + Co. Limited reported that no forward currency contracts were in place at the FY22 year end due to a broadly balanced profile of USD purchases and sales. Source: 2022 Annual Report, Financial Risk Management – Exchange rate risk (2022_radley.pdf, p.12)
#
# Sources:
# - Radley + Co. Limited Annual Report FY24 (52 weeks ended 27 Apr 2024): 2024_radley.pdf (pp.4, 14, 19, 55, 63)
# - Radley + Co. Limited Annual Report FY23 (53 weeks ended 29 Apr 2023): 2023_radley.pdf (pp.43, 54)
# - Radley + Co. Limited Annual Report FY22 (52 weeks ended 23 Apr 2022): 2022_radley.pdf (pp.12, 18, 50)
# 6. Key Stakeholders
# - Shareholders (ownership)
#   - Immediate parent company: n/a
#   - Ultimate parent company: n/a
#   - Source: Radley + Co. Limited Annual Reports FY22–FY24; no parent/ultimate parent disclosure identifiable in the provided extracts ([2022_radley.pdf] Company Information; [2023_radley.pdf] and [2024_radley.pdf] general sections) [5], [2], [4]
#
# - Management (board and executives)
#   - Chairman: n/a
#   - Chief Executive Officer: n/a
#   - Chief Financial Officer: n/a
#   - Directors: N Cooper; J Stead; N Vance
#   - Source: Company Information section (FY22) lists directors; FY24 Directors’ Report signed by N Cooper as Director [5], [11]
#
# - Lenders (by debt facility)
#   - n/a
#   - Source: Notes to the Financial Statements reviewed for borrowings/loans; no explicit disclosure of lender names or facilities in the provided extracts for FY22–FY24 [6], [8], [10], [2], [4]
#
# - Auditors (external)
#   - Ernst & Young LLP
#   - Source: Company Information (FY22) and FY24 Directors’ Report noting re-appointment of EY as auditors [5], [11]
#
# - Advisors (solicitors/bankers listed)
#   - Bankers: Barclays Bank plc; Wells Fargo Bank N.A.
#   - Solicitors: Willkie Farr & Gallagher (UK) LLP
#   - Source: Company Information section (FY22) [5]
# 7. Financial Highlights
#
# Financial summary (all figures in £m, rounded to 1 decimal; FY22 = 52 weeks to 23-Apr-22, FY23 = 53 weeks to 29-Apr-23, FY24 = 52 weeks to 27-Apr-24)
#
# - Revenue: FY22 n.a. | FY23 77.3 | FY24 72.0
# - Gross Profit: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - EBITDA: FY22 n.a. | FY23 4.3 | FY24 2.7
# - Revenue Growth %: FY22 n.a. | FY23 n.a. | FY24 -6.9%
# - Gross Margin %: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - EBITDA Margin %: FY22 n.a. | FY23 5.6% | FY24 3.7%
# - Cash Flow from Operating Activities excl. Net Working Capital: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - Net Working Capital (change): FY22 n.a. | FY23 n.a. | FY24 n.a.
# - Capex: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - Other Cash Flow from Investing Activities: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - CFADS: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - Cash Flow from Financing Activities: FY22 n.a. | FY23 n.a. | FY24 n.a.
# - Opening Cash: FY22 0.9 | FY23 1.4 | FY24 1.6
# - Change in Cash: FY22 0.5 | FY23 0.2 | FY24 n.a.
# - Closing Cash: FY22 1.4 | FY23 1.6 | FY24 n.a.
# - Total Debt: FY22 n.a. | FY23 9.6 | FY24 n.a.
# - Net Debt: FY22 n.a. | FY23 8.0 | FY24 10.8
# - Leverage (Net Debt / EBITDA): FY22 n.a. | FY23 1.9x | FY24 4.1x
#
# Notes on calculations and data availability:
# - EBITDA is as disclosed by the company (before non-recurring items and discontinued operations).
# - Total Debt for FY23 is derived as Net Debt plus Closing Cash, using the company’s definition of net debt which excludes shareholder loans and preference shares (in line with our Total Debt definition excluding related-party debt).
# - Cash balances for FY22 and FY23 are taken from the statement of financial position. FY24 cash flow statement and cash balance details were not available in the provided extracts; related cash flow items are shown as n.a.
# - Gross profit and cost of sales were not available in the provided extracts; therefore gross profit and gross margin are shown as n.a.
# - Where prior-year data was not available in the extracts, items are shown as n.a.
#
# Commentary on performance and trends
# - Revenue declined by 6.9% in FY24 to £72.0m from £77.3m as cost-of-living pressures weighed on UK consumer spend and international demand softened in EMEA and Asia Pacific, partially offset by modest growth in North America; UK revenue fell to £52.8m (from £56.0m), EMEA notably contracted to £0.5m (from £2.3m), Asia Pacific decreased to £2.1m (from £2.9m), while North America increased to £16.6m (from £16.0m)
# - EBITDA decreased to £2.7m in FY24 from £4.3m in FY23, reflecting the lower revenue base and a tougher trading environment with inflationary pressures on consumers and input costs that reduced operating efficiency despite ongoing cost controls
# - EBITDA margin compressed to 3.7% in FY24 from 5.6% in FY23 as top-line pressure and a less favorable regional mix weighed on operating profitability
# - Net debt (excluding shareholder loans and preference shares) increased to £10.8m in FY24 from £8.0m in FY23 as weaker earnings reduced deleveraging capacity; leverage therefore rose to 4.1x in FY24 from 1.9x in FY23, driven primarily by the decline in EBITDA
# - Cash balances increased modestly in FY23 to £1.6m from £1.4m, though FY24 cash movement is not disclosed in the extracts; the FY23 cash increase was small relative to net debt, highlighting limited free cash generation in the period
#
# Sources:
# - FY24 and FY23 turnover, operating loss, EBITDA before non-recurring items, and net debt excluding shareholder loans/preference shares: Radley + Co. Limited Annual Report FY24, Strategic Report/KPIs (Turnover £71.975m vs £77.310m; Operating loss £0.542m vs £0.748m; EBITDA £2.666m vs £4.344m; Net debt £10.848m vs £8.049m) [2024_radley.pdf, p.4]
# - FY24 vs FY23 revenue by geography and category: Radley + Co. Limited Annual Report FY24, Note 3 Turnover analysis (UK £52.832m; EMEA £0.494m; North America £16.590m; Asia Pacific £2.059m; Sales of goods £70.593m; Royalty income £1.382m) [2024_radley.pdf, p.55]
# - Macroeconomic and consumer pressures affecting trading conditions: Radley + Co. Limited Annual Report FY24, Strategic Report and going concern discussion [2024_radley.pdf, p.14]
# - Cash balances (closing): FY22 £1.372m and FY23 £1.572m from Statement of Financial Position [2023_radley.pdf, p.25]; prior-year comparator FY21 £0.867m and FY22 £1.372m from Statement of Financial Position [2022_radley.pdf, p.32]
# - FY24 debtor composition (for qualitative working capital context): Trade debtors broadly flat YoY; Radley + Co. Limited Annual Report FY24, Note 17 Debtors [2024_radley.pdf, p.63]
#
# Assumptions/limitations:
# - Cash flow statement line items for FY22–FY24, cost of sales, and depreciation/amortization were not available in the provided extracts; therefore Gross Profit, Gross Margin, CFO items, Capex, other investing cash flows, CFADS, and Financing cash flow breakdown could not be shown.
# - Total Debt for FY24 could not be derived due to missing FY24 cash balance in the extracts.
# 8. Capital Structure
#
# Capital structure (latest year: FY24)
#
# - Name of Facility: Revolving Credit Facility
#   Interest Rate: Not disclosed
#   Maturity: Not disclosed
#   Amount Outstanding: £11.1m
#
# - Name of Facility: Finance lease liabilities
#   Interest Rate: Not disclosed
#   Maturity: Not disclosed
#   Amount Outstanding: £0.1m
#
# - Gross External Debt: £11.2m
# - Cash: £0.9m
# - Net External Debt: £10.3m
# - Liquidity: £0.9m
# - EBITDA: n/a
# - Leverage (Net Debt / EBITDA): n/a
#
# Commentary
#
# - Net debt increased year over year as RCF drawings rose to £11.1m in FY24 from £10.0m in FY23 and cash decreased to £0.9m from £1.9m, resulting in higher net external debt and a tighter liquidity cushion.
# - Liquidity at year end was modest with £0.9m of cash on hand and no disclosed information on undrawn committed facilities, which indicates limited immediate headroom absent additional availability under bank lines.
# - Upcoming maturities are not specified in the notes, but the presence of £12.7m of creditors due after more than one year at FY24 suggests the principal bank borrowing is classified as long-term and does not fall due within 12 months.
#
# Sources
#
# - Radley + Co. Limited, FY24 Annual Report and Financial Statements, Note 20 Financial instruments (Revolving credit facility £11.111m; finance lease liabilities £0.062m; trade creditors), and comparatives for FY23 (£9.975m RCF; £0.116m finance lease) [2024_radley.pdf, p.65].
# - Radley + Co. Limited, FY24 Consolidated Statement of Financial Position (cash at bank and in hand £0.884m; creditors due after more than one year £12.653m) [2024_radley.pdf, p.32].

# %% [markdown]
# # 2 RAG Opt with HyDE

# %%
import json, re
from typing import List, Dict

def hyde_optimizer(question: str) -> Dict:
    """
    Returns a JSON plan:
      {
        "canonical": "...",                  # tightened canonical query
        "aliases": ["...", "..."],           # entity variants
        "must_terms": ["annual report"],     # hard lexical hints
        "year_hint": "2019..2025",           # optional
        "hyde": "≤120-word hypothetical answer paragraph",
        "rewrites": ["q1", "q2", "q3", "q4"] # diverse facets
      }
    """
    client = get_aoai_client()
    system = (
        "Rewrite the user's ask for enterprise retrieval.\n"
        "- Normalize named entities (legal names, brand variants, tickers).\n"
        "- Add must-have lexical terms if obvious (e.g., 'annual report').\n"
        "- Produce 1 HyDE paragraph (<=120 words).\n"
        "- Produce 4 short diverse rewrites (<=12 tokens each) that cover different facets.\n"
        "- If a year range is implied, include it as 'YYYY..YYYY'."
        "Output strict JSON with keys: canonical, aliases, must_terms, year_hint, hyde, rewrites."
    )
    user = f"User question:\n{question}\nReturn ONLY JSON."

    resp = client.chat.completions.create(
        model=AOAI_DEPLOYMENT,
        messages=[{"role":"system","content":system},{"role":"user","content":user}]
    )
    text = resp.choices[0].message.content.strip()
    try:
        plan = json.loads(text)
    except Exception:
        # ultra-safe fallback
        plan = {
            "canonical": question,
            "aliases": [],
            "must_terms": [],
            "year_hint": "",
            "hyde": question,      # use the question itself if JSON parse fails
            "rewrites": []
        }
    return plan

def hyde_build_bm25_query(plan: Dict) -> str:
    # Canonical + must_terms + hints; keep it short for BM25
    parts = [plan.get("canonical","")]
    parts += plan.get("aliases", [])[:2]  # at most a couple to avoid noise
    parts += plan.get("must_terms", [])
    if plan.get("year_hint"):
        parts.append(plan["year_hint"])
    bm25 = " ".join(p for p in parts if p).strip()
    return re.sub(r"\s+", " ", bm25)

def hyde_build_vector_queries(plan: Dict, per_k: int = 25) -> List:
    """
    Multiple VectorizableTextQuery items in ONE call.
    Azure will RRF-merge them (and then semantic re-rank).
    Weights bias which vectors matter more.
    """
    vqs = []
    # HyDE gets the highest weight
    vqs.append(VectorizableTextQuery(text=plan.get("hyde") or plan.get("canonical",""),
                                     k=per_k, fields=VECTOR_FIELD, weight=2.0))
    # Canonical question
    vqs.append(VectorizableTextQuery(text=plan.get("canonical",""),
                                     k=per_k, fields=VECTOR_FIELD, weight=1.6))
    # Diverse rewrites
    for q in plan.get("rewrites", [])[:4]:
        vqs.append(VectorizableTextQuery(text=q, k=per_k, fields=VECTOR_FIELD, weight=1.2))
    return vqs

# %%
def retrieve_hybrid_enhanced(query: str, top: int = 20, k: int = 50, max_text_recall_size:int = 200):
    sc = get_search_client()

    plan = hyde_optimizer(query)
    bm25 = hyde_build_bm25_query(plan)
    vqs  = hyde_build_vector_queries(plan, per_k=k)

    try:
        
        # Prefer vector-only search (integrated vectorization). If your index isn't set up for it, this raises.
        results = sc.search(
            search_text=bm25, 
            vector_queries=vqs,
            top=top, 
            query_type="semantic",
            query_caption="extractive", 
            query_answer='extractive',
            hybrid_search=HybridSearch(max_text_recall_size=max_text_recall_size),
            query_caption_highlight_enabled=True,
            semantic_error_mode="partial"
            )
        mode = "hybrid + semantic"
    except HttpResponseError as e:
        # Fall back to lexical so you still get results while fixing vector config
        results = sc.search(search_text=query, top=k)
        mode = f"lexical (fallback due to: {e.__class__.__name__})"

    hits: List[Dict] = []
    for r in results:
        d = r.copy() if hasattr(r, "copy") else {k2: r[k2] for k2 in r}
        d["score"] = d.get("@search.reranker_score") or d.get("@search.score") or 0.0
        caps = d.get("@search.captions")
        if isinstance(caps, list) and caps:
            d["caption"] = getattr(caps[0], "text", None)
        hits.append(d)

    answers = getattr(results, "answers", None) or []
    semantic_answer = answers[0].text if answers else None  # SDK shape may vary. See docs. :contentReference[oaicite:5]{index=5}


    return mode, hits, plan, semantic_answer

# %%
def build_context(hits: List[Dict], text_field: str = TEXT_FIELD, max_chars: int = 20000) -> str:
    """Build a compact, numbered context block to feed the model."""
    lines = []
    total = 0
    for i, h in enumerate(hits, 1):
        title     = h.get("title")
        chunk_id  = h.get("chunk_id")
        snippet   = (h.get(text_field) or "")
        if not snippet:
            continue
        snippet = textwrap.shorten(snippet, width=700, placeholder=" ...")
        block = f"[{i}] title={title!r} | chunk_id={chunk_id} | score={h.get('score'):.4f}\n{snippet}"
        if total + len(block) > max_chars:
            break
        total += len(block)
        lines.append(block)
    return "\n\n---\n\n".join(lines)

# %%
from prompts import new_system_finance_prompt
def rag_answer(question: str, k: int = 20, temperature: float = 0.2):

    mode, hits, plan, semantic_answer = retrieve_hybrid_enhanced(question, k=k)
    ctx = build_context(hits)
    client = get_aoai_client()

    if semantic_answer:
        ctx = f"Answer span (verbatim): {semantic_answer}\n---\n{ctx}"
    
    question = f"Create the company profile of Radley + Co. Limited."

    system_msg = new_system_finance_prompt
    user_msg = f"Question:\n{question}\n\nContext snippets (numbered):\n{ctx}"

    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user",   "content": user_msg},
    ]

    # Try streaming first (SSE). Some networks/proxies block streaming; if so, fall back.
    try:
        text = ""
        stream = client.chat.completions.create(
            model=AOAI_DEPLOYMENT,
            messages=messages,
            stream=True,
            stream_options={"include_usage": True},
        )
        for chunk in stream:
            choices = getattr(chunk, "choices", None)
            if not choices:
                continue
            delta = getattr(choices[0], "delta", None)
            if not delta:
                continue
            piece = getattr(delta, "content", None)
            if piece:
                text += piece
        answer = text if text else "(no text returned)"
        mode_model = "streaming"
    except APIConnectionError:
        resp = client.chat.completions.create(
            model=AOAI_DEPLOYMENT,
            messages=messages,
        )
        answer = resp.choices[0].message.content
        mode_model = "non-streaming (fallback)"

    return {
        "search_mode": mode,
        "model_mode": mode_model,
        "answer": answer,
        "optimizer_plan": plan,
        "sources": [
            {"n": i+1, "title": h.get("title"), "chunk_id": h.get("chunk_id"), "score": h.get("score")}
            for i, h in enumerate(hits)
        ],
    }

# %%
answer = rag_answer(question="Create the company profile of Radley + Co. Limited.")
print(answer['answer'])
# Out:
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# Radley + Co. Limited – One‑Pager Restructuring Profile
# Sources used: FY24 annual report for the 52 weeks ended 27 Apr-24 (Radley+Co Limited), FY23 annual report for the 53 weeks ended 29 Apr-23, FY22 annual report for the 52 weeks ended 23 Apr-22. Exact page and note references are cited per section below.
#
# 1) Introduction Table (Company Snapshot)
# - Primary Industry: Fashion accessories
#   Source: FY24 AR, Notes, Note 1 “General information” and principal activity (p.19+ per contents; also p.37 of PDF view)
# - Incorporation Year: n/a
#   Source: n/a in reports reviewed
# - Headquarters: Milton Keynes, United Kingdom
#   Source: FY24 AR, Company Information, Registered office (company information page; also p.1 of PDF view)
# - Number of Employees: n/a
#   Source: n/a in reports reviewed
# - Operational KPIs: n/a
#   Source: n/a in reports reviewed
#
# 2) Business Overview
# - The company offers multi‑channel distribution of the Radley London affordable luxury accessories brand across wholesale and direct channels. Source: FY24 AR, Notes, Note 1 “General information” and principal activity (p.19+; PDF p.37)
# - The company designs, markets and sells branded accessories positioned as affordable luxury under the Radley London brand. Source: FY24 AR, Notes, Note 1 “General information” (p.19+; PDF p.37)
# - The company has operations centered in the United Kingdom with wholesale distribution in Europe and Asia and has identified the USA as a key strategic growth market. Sources: FY22 AR, Strategic Report introduction (p.1–2); FY23 AR, Strategic Report commentary on USA as key growth market (p.1–2; PDF p.4)
# - The company sells through wholesale partners across major digital marketplaces and department stores complemented by direct to consumer channels. Source: FY22 AR, Strategic Report (p.1–2)
# - The company is experiencing financial pressure with turnover declining to £72.0m in FY24 from £77.3m in FY23, EBITDA before non‑recurring items falling to £2.7m from £4.3m, and a loss after tax of £1.9m with no dividend recommended. Source: FY24 AR, Directors’ Report “Results and dividends” (p.6–7; PDF p.13)
#
# 3) Revenue Split
# - Not available in the financial statements reviewed; no segmental or geographic revenue breakdown was found in the notes provided.
#   Source: n/a in FY24/FY23/FY22 reports reviewed
#
# 4a) Products/Services Overview
# - Detailed product and service listing was not provided in the sections reviewed beyond the brand positioning as affordable luxury accessories.
#   Source: FY24 AR, Notes, Note 1 “General information” (p.19+; PDF p.37)
#
# 4b) Geographical Footprint
# - United Kingdom: Registered office and operating headquarters; multi‑channel operations
#   Source: FY24 AR, Company Information, Registered office (company information page)
# - United States: Key strategic growth market for group sales
#   Source: FY23 AR, Strategic Report (p.1–2; PDF p.4)
# - China: Business migrated to a distribution partner arrangement during FY22
#   Source: FY22 AR, Strategic Report (p.2; PDF p.4–5)
# - Netherlands: Operated one store contributing c.0.5% of external group sales in FY23; store closed in May-23
#   Source: FY23 AR, Strategic Report (p.2; PDF p.4)
#
# 5) Key Recent Developments
# - May-25: Radley + Co. Limited filed its FY24 annual report covering the 52 weeks ended 27 Apr-24 at Companies House. Source: FY24 AR cover page (PDF p.1)
# - Apr-24: Radley + Co. Limited reported group turnover decreased to £72.0m and EBITDA before non‑recurring items decreased to £2.7m with a loss after tax of £1.9m and no final dividend recommended. Source: FY24 AR, Directors’ Report “Results and dividends” (p.6–7; PDF p.13)
# - Apr-24: Radley + Co. Limited increased drawings on its revolving credit facility resulting in net debt of £10.8m including £11.1m RCF and £0.6m finance lease liabilities at period end. Source: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (p.27–28 of notes; PDF p.67)
# - Apr-24: Radley + Co. Limited reclassified certain selling and distribution expenses versus other administrative expenses following a review of classifications. Source: FY24 AR, Notes, Note 28 Reclassification (p.28 of notes; PDF p.67)
# - Apr-23: Radley + Co. Limited implemented the first stage of a legal entity rationalisation transferring the net assets of Radley Retail Limited and Radley Outlets Limited to Radley + Co. Limited at net book value. Source: FY23 AR, Strategic Report (p.2; PDF p.4)
# - May-23: Radley Netherlands B.V. closed its one store in the Netherlands following a period where it contributed 0.5% of external group sales. Source: FY23 AR, Strategic Report (p.2; PDF p.4)
# - Apr-22: Radley China Limited migrated to a distribution partner arrangement with group sales to this partner reported in Radley + Co. Limited. Source: FY22 AR, Strategic Report (p.2; PDF p.4–5)
#
# 6) Key Stakeholders
# Shareholders
# - Immediate parent: n/a
# - Ultimate parent: n/a
# Source: FY24/FY23/FY22 ARs – not disclosed in the sections reviewed; FY22 Strategic Report notes the group is headed by a Topco but the exact legal name was not verifiable from OCR, so not stated (FY22 AR, Strategic Report p.1)
#
# Management
# - Directors: N. Cooper; N. Vance
# Source: FY24 AR, Company Information (company information page; PDF p.2)
# - Chairman: n/a; CEO: n/a; CFO: n/a
# Source: not disclosed on Company Information page; FY22 AR includes a CEO statement by Justin Stead as group CEO but role listings are not clearly enumerated in FY24 (FY22 AR, Strategic Report p.5; FY24 AR company information)
#
# Lenders
# - Revolving Credit Facility lender: n/a in notes reviewed
# - Finance lease provider: n/a
# Source: Facility lenders not named in notes excerpt; see FY24 AR, Notes, Net debt analysis (Note 27) (PDF p.67)
#
# Auditors
# - Ernst & Young LLP
# Source: FY24 AR, Company Information (company information page; PDF p.2)
#
# Advisors/Bankers
# - Bankers: Barclays Bank plc; Wells Fargo Bank NA
# Source: FY24 AR, Company Information (company information page; PDF p.2)
#
# 7) Financial Highlights
# All figures in £ millions; fiscal years end Apr-24/Apr-23/Apr-22; rounding to 1 decimal. EBITDA figures are before non‑recurring items as stated in the reports. n.a. indicates not available in the sections reviewed.
#
# - Revenue: FY24 72.0; FY23 77.3; FY22 n.a.
#   Source: FY24 AR, Directors’ Report “Results and dividends” (p.6–7; PDF p.13)
# - Gross Profit: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - EBITDA: FY24 2.7; FY23 4.3; FY22 5.3
#   Sources: FY24 AR, Directors’ Report (p.6–7); FY23 value from same; FY22 AR, Strategic Report CEO commentary referencing underlying EBITDA c.£5.3m (p.5; PDF p.5)
# - Revenue Growth %: FY24 -6.9%; FY23 n.a.; FY22 n.a.
#   Source: Calculated from revenue above for FY24; prior years not available
# - Gross Margin %: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - EBITDA Margin %: FY24 3.7%; FY23 5.6%; FY22 n.a.
#   Source: Calculated from revenue and EBITDA figures above
# - Cash Flow from Operating Activities excl. Net Working Capital: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - Net Working Capital (cash flow definition): FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - Capex: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - Other Cash Flow from Investing Activities: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - CFADS: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Source: n/a
# - Cash Flow from Financing Activities: FY24 n.a.; FY23 n.a.; FY22 n.a.
#   Notes: Net debt analysis indicates RCF draw of £1.1m and finance lease addition of £0.6m in FY24 but full CFF breakdown not shown in excerpts
#   Source: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - Opening Cash: FY24 1.9; FY23 n.a.; FY22 n.a.
#   Source: FY24 AR, Notes, Analysis of changes in net debt shows opening cash £1.926m (Note 27) (PDF p.67)
# - Change in Cash: FY24 -1.0; FY23 n.a.; FY22 n.a.
#   Source: FY24 AR, Notes, Analysis of changes in net debt shows cash decreased by £1.042m (Note 27) (PDF p.67)
# - Closing Cash: FY24 0.9; FY23 1.9; FY22 n.a.
#   Sources: FY24 AR, Consolidated Statement of Financial Position, Cash at bank and in hand £0.884m (p.14; PDF p.32). FY23 closing cash per net debt analysis £1.926m (Note 27) (PDF p.67)
# - Total Debt (external + finance leases): FY24 11.7; FY23 10.0; FY22 n.a.
#   Sources: FY24 AR, Notes, Analysis of changes in net debt shows RCF £11.111m and finance lease £0.621m (Note 27) (PDF p.67); FY23 RCF £9.975m and no finance lease (Note 27) (PDF p.67)
# - Net Debt: FY24 10.8; FY23 8.0; FY22 n.a.
#   Source: FY24 AR, Notes, Analysis of changes in net debt total of £10.848m in FY24 and £8.049m in FY23 (Note 27) (PDF p.67)
# - Leverage (Net Debt/EBITDA): FY24 4.1x; FY23 1.9x; FY22 n.a.
#   Source: Calculated using EBITDA above and net debt from Note 27
#
# Commentary
# - Revenue decreased by 6.9% to £72.0m in FY24 from £77.3m in FY23 reflecting a softer trading period, as disclosed in the Directors’ Report, which also notes that the group reported a loss after tax. Source: FY24 AR, Directors’ Report (p.6–7; PDF p.13)
# - EBITDA before non‑recurring items declined to £2.7m in FY24 from £4.3m in FY23, consistent with the lower turnover and a weaker operating performance. Source: FY24 AR, Directors’ Report (p.6–7; PDF p.13)
# - Cash on hand fell by £1.0m to £0.9m in FY24 while the group increased RCF drawings by £1.1m and added £0.6m of finance leases, contributing to higher net debt. Source: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - Total external debt increased to £11.7m in FY24 from £10.0m in FY23 driven by higher RCF utilisation and the introduction of finance leases, pushing leverage to 4.1x from 1.9x year on year. Sources: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (PDF p.67); FY24 AR, Directors’ Report (p.6–7)
#
# 8) Capital Structure (latest year FY24)
# Facilities and metrics in £ millions (rounded)
#
# - Revolving Credit Facility | Interest rate: n/a | Maturity: n/a | Amount outstanding: 11.1
#   Source: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - Finance lease liabilities | Interest rate: n/a | Maturity: n/a | Amount outstanding: 0.6
#   Source: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - Gross External Debt: 11.7
#   Source: Sum of above
# - Cash: 0.9
#   Source: FY24 AR, Consolidated Statement of Financial Position, cash at bank and in hand £0.884m (p.14; PDF p.32)
# - Net External Debt: 10.8
#   Source: FY24 AR, Notes, Analysis of changes in net debt, total £10.848m (Note 27) (PDF p.67)
# - Liquidity: 0.9
#   Source: Cash only; undrawn committed facilities not disclosed in excerpts
# - EBITDA: 2.7
#   Source: FY24 AR, Directors’ Report EBITDA before non‑recurring items (p.6–7; PDF p.13)
# - Leverage (Net Debt/EBITDA): 4.1x
#   Source: Calculated
#
# Capital Structure Commentary
# - Net debt increased by approximately £2.8m year on year to £10.8m in FY24 and leverage rose to 4.1x as EBITDA fell and the group drew further on its revolving credit facility. Sources: FY24 AR, Directors’ Report (p.6–7; PDF p.13); Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - The group utilised additional RCF capacity and introduced finance leases in FY24 but no specific refinancing transactions were disclosed in the excerpts reviewed. Source: FY24 AR, Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - Debt covenant terms and recent covenant tests were not disclosed in the materials reviewed. Source: n/a in FY24 AR excerpts
# - Security and collateral for the debt facilities were not disclosed in the materials reviewed. Source: n/a in FY24 AR excerpts
# - Liquidity at year end comprised £0.9m of cash and any undrawn RCF headroom was not disclosed, indicating reliance on revolving facilities amid low cash balances. Sources: FY24 AR, Consolidated Statement of Financial Position (p.14; PDF p.32); Notes, Analysis of changes in net debt (Note 27) (PDF p.67)
# - Upcoming maturities for the RCF and lease obligations were not disclosed in the excerpts reviewed. Source: n/a in FY24 AR excerpts
#
# Notes and Data Availability
# - Several data points, including employee count, detailed product listings, revenue splits, cash flow breakdowns, covenant terms, and facility pricing and maturities, were not available in the report sections provided. If you can share the full FY24 PDF with all notes or specific pages for staff numbers, segmental disclosure, and borrowing notes, I can complete the missing items.

# %% [markdown]
# # 3 Add re-retreavel

# %%
from typing import Dict, List, Tuple

def _distinct_docs(hits: List[Dict]) -> int:
    # adjust keys if you have a stable doc id field
    keys = []
    for h in hits:
        # Prefer an explicit doc id if present; otherwise title is a usable proxy
        keys.append(h.get("id") or h.get("document_id") or h.get("title") or h.get("chunk_id"))
    return len(set([k for k in keys if k]))

def _avg_reranker_score(hits: List[Dict]) -> float:
    scores = [float(h.get("score") or 0.0) for h in hits]
    return sum(scores)/len(scores) if scores else 0.0

def is_grounded(hits: List[Dict],
                min_docs: int = 2,
                min_avg_score: float = 0.20) -> Tuple[bool, Dict]:
    grounded = True
    reasons = {}
    if _distinct_docs(hits) < min_docs:
        grounded = False
        reasons["too_few_docs"] = _distinct_docs(hits)
    if _avg_reranker_score(hits) < min_avg_score:
        grounded = False
        reasons["low_avg_score"] = round(_avg_reranker_score(hits), 4)
    return grounded, reasons

def reretrieve_until_grounded(
    query: str,
    *,
    attempt_profiles=None,
    max_attempts: int = 3,
) -> Tuple[str, List[Dict], Dict]:
    """
    Returns: (mode_used, hits, debug_info)
    attempt_profiles: list of dicts with {top, k, max_text_recall_size, query_override?}
    """
    if attempt_profiles is None:
        attempt_profiles = [
            # Attempt 1: your current defaults
            dict(top=20, k=50, max_text_recall_size=200, label="baseline"),
            # Attempt 2: widen both legs of hybrid (BM25 + vector)
            dict(top=30, k=80, max_text_recall_size=500, label="widen_recall"),
            # Attempt 3: lightweight rewrite (no HyDE required)
            dict(top=30, k=80, max_text_recall_size=800, label="rewrite"),
        ]

    debug = {"attempts": []}
    last_mode, last_hits = "n/a", []

    for i, prof in enumerate(attempt_profiles, 1):
        q = query
        if prof.get("label") == "rewrite":
            # very small, safe rewrite to help BM25 and vector
            # (You can swap in your GPT optimizer here if you want stronger reformulations.)
            q = simple_query_rewrite(query)

        mode, hits = retrieve_hybrid_enhanced(
            q,
            top=prof["top"],
            k=prof["k"],
            max_text_recall_size=prof["max_text_recall_size"]
        )
        grounded, reasons = is_grounded(hits)
        debug["attempts"].append({
            "attempt": i,
            "label": prof.get("label"),
            "params": prof,
            "grounded": grounded,
            "reasons": reasons,
            "num_hits": len(hits),
            "distinct_docs": _distinct_docs(hits),
            "avg_score": _avg_reranker_score(hits),
            "mode": mode,
        })
        last_mode, last_hits = mode, hits

        if grounded:
            return mode, hits, debug

    # If nothing satisfied the grounding rules, return the strongest attempt (last one)
    return last_mode, last_hits, debug


def simple_query_rewrite(q: str) -> str:
    """Deterministic, zero-dependence cleanup that often helps both BM25 and vectors."""
    # normalize whitespace/quotes, remove unhelpful filler words
    import re
    q2 = q.strip().replace("’", "'").replace("“", '"').replace("”", '"')
    q2 = re.sub(r"\b(please|could you|can you|tell me|about)\b", "", q2, flags=re.I)
    q2 = re.sub(r"\s+", " ", q2).strip()
    return q2 or q

# %%
from prompts import new_system_finance_prompt
def rag_answer(question: str):

    client = get_aoai_client()

    question = f"Create the company profile of Radley + Co. Limited."

    mode, hits, debug = reretrieve_until_grounded(question)
    ctx = build_context(hits)

    system_msg = new_system_finance_prompt
    user_msg = f"Question:\n{question}\n\n Context snippets (numbered):\n{ctx}"

    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user",   "content": user_msg},
    ]

    # Try streaming first (SSE). Some networks/proxies block streaming; if so, fall back.
    try:
        text = ""
        stream = client.chat.completions.create(
            model=AOAI_DEPLOYMENT,
            messages=messages,
            stream=True,
            stream_options={"include_usage": True},
        )
        for chunk in stream:
            choices = getattr(chunk, "choices", None)
            if not choices:
                continue
            delta = getattr(choices[0], "delta", None)
            if not delta:
                continue
            piece = getattr(delta, "content", None)
            if piece:
                text += piece
        answer = text if text else "(no text returned)"
        mode_model = "streaming"
    except APIConnectionError:
        resp = client.chat.completions.create(
            model=AOAI_DEPLOYMENT,
            messages=messages,
        )
        answer = resp.choices[0].message.content
        mode_model = "non-streaming (fallback)"

    return {
        "search_mode": mode,
        "model_mode": mode_model,
        "answer": answer,
        "retrieval_debug": debug,   # handy for tuning
        "sources": [
            {"n": i+1, "title": h.get("title"), "chunk_id": h.get("chunk_id"), "score": h.get("score")}
            for i, h in enumerate(hits)
        ],
    }

# %%
answer = rag_answer(question="Create the company profile of Radley + Co. Limited.")
print(answer['answer'])
# Out:
# k is not a known attribute of class <class 'azure.search.documents._generated.models._models_py3.VectorizableTextQuery'> and will be ignored
# Company profile: Radley + Co. Limited
#
# 1) Introduction Table (Company Snapshot)
# - Source: 2024 AR p.3, p.37; 2024 AR p.1
#
# | Item | Detail |
# | --- | --- |
# | Primary Industry | Fashion accessories |
# | Incorporation Year | n/a |
# | Headquarters (city, country) | Milton Keynes, United Kingdom |
# | Number of Employees | n/a |
# | Operational KPIs | Operated 2 high street stores, 17 outlets and 36 concessions in the period |
#
# Sources:
# - Principal activities and operating footprint: 2024 Annual Report (AR), Strategic Report, p.3
# - General information and registered office: 2024 AR, Notes, p.37; Company information page listing registered office: 2024 AR p.1
#
# 2) Business Overview
# - The company operates a multi-channel distribution business for Radley goods, positioning Radley as a modern British icon of accessible luxury and an expert in handbags and accessories (2024 AR p.3).
# - The company manages the group’s U.K., European and Asian direct-to-consumer and wholesale distribution and it operated 2 high street stores, 17 outlets and 36 concessions during the period (2024 AR p.3).
# - The company offers handbags and accessories under the Radley London brand to customers across physical retail and online channels (2024 AR p.3).
# - The company serves retail consumers through its own stores, outlets and concessions and wholesale and marketplace partners across the U.K., Europe and Asia (2024 AR p.3).
# - The company experienced a decline in turnover and EBITDA in FY24 and reported a loss after tax, with directors highlighting continued focus on profitability and liquidity amid consumer pressure and liquidity risk management (2024 AR p.13; 2023 AR p.8).
#
# Sources:
# - 2024 AR, Strategic Report (Principal activities), p.3
# - 2024 AR, Directors’ Report (results summary), p.13
# - 2023 AR, Strategic Report (financial risk management including liquidity risk), p.8
#
# 3) Revenue Split
# - Disclosure not available in the accessible sections of the latest annual reports; no segmental or geographic revenue split was found in the excerpts reviewed.
#
# Source:
# - Not identified in available Notes/segment disclosures in provided excerpts of the 2024 AR and 2023 AR. If you can share the full Notes to the financial statements (Revenue/Segmental Analysis), I can add this.
#
# 4a) Products/Services Overview
# - Handbags and accessories: The company markets the Radley London brand as an accessible luxury expert in handbags and accessories, sold via direct-to-consumer and wholesale channels, including owned stores, outlets, concessions and digital marketplaces (2024 AR p.3).
#
# Source:
# - 2024 AR, Strategic Report (Principal activities), p.3
#
# Note: More granular product family detail is not available in the provided report excerpts.
#
# 4b) Geographical Footprint
# - Source: 2024 AR p.3; 2023 AR p.4; 2024 AR p.37
#
# | Country | Office | Manufacturing Facility | Sales Office | Retail Presence |
# | --- | --- | --- | --- | --- |
# | United Kingdom | Yes, registered office in Milton Keynes | n/a | n/a | Yes, 2 high street stores, 17 outlets, 36 concessions |
# | Netherlands | n/a | n/a | n/a | Store closed in May-23 |
# | Other Europe | n/a | n/a | n/a | n/a |
# | Asia | n/a | n/a | n/a | n/a |
#
# Notes:
# - The company manages U.K., European and Asian direct-to-consumer and wholesale distribution, but precise country-by-country facility locations beyond the UK and the now-closed Netherlands store were not disclosed in the excerpts (2024 AR p.3; 2023 AR p.4; 2024 AR p.37).
#
# 5) Key Recent Developments (last three years)
# - Apr-24: Radley + Co. Limited reported FY24 group turnover of £72.0m, EBITDA before non-recurring items of £2.7m and a loss after tax of £1.9m, and the directors did not recommend a final dividend (2024 AR p.13).
# - Apr-24: Radley + Co. Limited increased drawings on its revolving credit facility to £11.1m and ended the year with £0.9m cash, with total net debt at £10.8m based on the net debt reconciliation (2024 AR p.67).
# - May-23: Radley + Co. Limited closed its Netherlands store, which had contributed 0.5% of external group sales in FY23 (2023 AR p.4).
# - Apr-23: Radley + Co. Limited implemented the first stage of a legal entity rationalisation transferring the net assets of Radley Retail Limited and Radley Outlets Limited to Radley + Co Limited at net book value to simplify the structure, with a second stage planned subsequently (2023 AR p.4).
# - Apr-22: Radley + Co. Limited reported FY22 company turnover of £47.5m and an operating loss before non-recurring items of £2.8m, reflecting post-pandemic trading dynamics and recovery trajectory described by management (2022 AR p.5).
#
# Sources:
# - 2024 AR, Directors’ Report (results), p.13; Notes (net debt reconciliation), p.67
# - 2023 AR, Strategic Report (Netherlands store closure; legal entity rationalisation), p.4
# - 2022 AR, Strategic Report (FY22 company results), p.5
#
# 6) Key Stakeholders
# - Sources: 2024 AR p.1; 2024 AR p.13; 2022 AR p.3; 2023 AR p.27
#
# | Category | Detail |
# | --- | --- |
# | Shareholders | Immediate parent: n/a; Ultimate parent: Laddie Topco Limited (group headed by Laddie Topco Limited) |
# | Management | Directors: N Cooper; N Vance |
# | Lenders | Barclays Bank plc; Wells Fargo Bank NA |
# | Auditors | Ernst & Young LLP |
# | Advisors | n/a |
#
# Sources:
# - Parent/Group head: 2022 AR, Strategic Report, p.3
# - Directors, auditors, bankers: 2024 AR, Company Information, p.1; 2024 AR, Directors’ Report, p.13
# - General information: 2023 AR, Notes, p.27
#
# Note: Chairman, CEO and CFO names for Radley + Co. Limited were not disclosed in the provided excerpts; the group CEO referenced elsewhere is Justin Stead (2022 AR p.5), but specific company officer roles were not listed beyond directors.
#
# 7) Financial Highlights
# - Currency: £ millions; fiscal years end Apr; values rounded to 1 decimal. EBITDA as disclosed in reports is “before non-recurring items” and, in FY24, excludes discontinued operations.
#
# Financial summary table
# - Sources: 2024 AR p.13, p.67; 2023 AR p.27
# - Note: FY22 group-level detail and full cash flow statement line items were not available in the excerpts. Where not available, n.a. is shown.
#
# | Metric | FY24 | FY23 | FY22 |
# | --- | ---:| ---:| ---:|
# | Revenue | £72.0m | £77.3m | n.a. |
# | Gross Profit | n.a. | n.a. | n.a. |
# | EBITDA | £2.7m | £4.3m | n.a. |
# | Revenue Growth % | -6.9% | n.a. | n.a. |
# | Gross Margin % | n.a. | n.a. | n.a. |
# | EBITDA Margin % | 3.7% | 5.6% | n.a. |
# | Cash Flow from Operating Activities excl. NWC | n.a. | n.a. | n.a. |
# | Net Working Capital (change) | n.a. | n.a. | n.a. |
# | Capex | n.a. | n.a. | n.a. |
# | Other Cash Flow from Investing Activities | n.a. | n.a. | n.a. |
# | CFADS | n.a. | n.a. | n.a. |
# | Cash Flow from Financing Activities | n.a. | n.a. | n.a. |
# | Opening Cash | £1.9m | n.a. | n.a. |
# | Change in Cash | -£1.0m | n.a. | n.a. |
# | Closing Cash | £0.9m | £1.9m | n.a. |
# | Total Debt (external + finance leases) | £11.7m | £10.0m | n.a. |
# | Net Debt | £10.8m | £8.0m | n.a. |
# | Leverage (Net Debt/EBITDA) | 4.1x | 1.9x | n.a. |
#
# Underlying data and calculations:
# - Revenue: FY24 £71.975m; FY23 £77.310m (2024 AR p.13)
# - EBITDA: FY24 £2.666m; FY23 £4.344m (2024 AR p.13)
# - Cash: FY24 closing £0.884m; FY23 closing £1.926m; change in cash FY24 -£1.042m; opening cash FY24 £1.926m (2024 AR p.67)
# - Debt: RCF FY24 £11.111m; finance lease FY24 £0.621m; total debt FY24 £11.732m; RCF FY23 £9.975m; finance lease FY23 £0.000m; total debt FY23 £9.975m; net debt FY24 £10.848m; net debt FY23 £8.049m (2024 AR p.67)
# - Revenue growth FY24: (71.975/77.310) - 1 = -6.9%; EBITDA margins calculated as EBITDA/Revenue.
#
# Commentary on financial performance
# - Revenue decreased by 6.9% in FY24 to £72.0m from £77.3m in FY23 as management cited pressure on consumer disposable income from inflation in essentials and interest rates, which the company considered in its forecasting and liquidity planning (2024 AR p.13; 2023 AR p.8).
# - EBITDA declined to £2.7m in FY24 from £4.3m in FY23, reflecting the revenue contraction and a lower EBITDA margin of 3.7% versus 5.6% in FY23, indicating reduced operating profitability amid a softer consumer environment (2024 AR p.13).
# - Cash decreased by £1.0m in FY24 to £0.9m, with closing cash at £0.9m and increased RCF drawings, signaling tighter liquidity at year-end (2024 AR p.67).
# - Financing cash flows were not disclosed in the excerpts, but the net debt reconciliation indicates an additional £1.1m of RCF drawings in FY24 and the recognition of £0.6m of finance leases, contributing to higher gross and net debt (2024 AR p.67).
# - Total external debt increased to £11.7m in FY24 from £10.0m in FY23 and net debt rose to £10.8m, while leverage increased to 4.1x from 1.9x due to both higher debt and lower EBITDA, pointing to rising balance sheet pressure (2024 AR p.13; p.67).
#
# Sources:
# - Results and EBITDA measures: 2024 AR, Directors’ Report, p.13
# - Net debt and cash reconciliation: 2024 AR, Notes, p.67
# - Liquidity and consumer environment context: 2023 AR, Strategic Report, p.8
#
# 8) Capital Structure (latest year)
# - Source: 2024 AR p.67; 2024 AR p.1; 2024 AR p.13
#
# Capital structure table (FY24)
# | Facility | Interest Rate | Maturity | Amount Outstanding |
# | --- | --- | --- | ---:|
# | Revolving Credit Facility | n/a | n/a | £11.1m |
# | Finance lease liabilities | n/a | n/a | £0.6m |
# | Gross External Debt |  |  | £11.7m |
# | Cash (closing) |  |  | £0.9m |
# | Net External Debt |  |  | £10.8m |
# | Liquidity (Cash + undrawn) |  |  | £0.9m plus any undrawn facilities, n/a disclosed |
# | EBITDA (FY24) |  |  | £2.7m |
# | Leverage (Net Debt/EBITDA) |  |  | 4.1x |
#
# Notes:
# - Amounts are as at 27 Apr 2024 from the net debt reconciliation (2024 AR p.67).
# - EBITDA is EBITDA before non-recurring items and discontinued operations per Directors’ Report (2024 AR p.13).
# - No disclosure of interest rates, maturities or undrawn headroom was found in the provided excerpts.
#
# Capital structure commentary
# - Net debt increased to £10.8m and leverage rose to 4.1x in FY24 from 1.9x in FY23 due to lower EBITDA and higher drawings on the revolving credit facility, indicating reduced financial headroom (2024 AR p.13; p.67).
# - The company’s bankers are Barclays Bank plc and Wells Fargo Bank NA, and FY24 funding relied on the revolving credit facility, which increased by £1.1m year over year according to the net debt analysis (2024 AR p.1; p.67).
# - Liquidity at year-end comprised £0.9m of cash with any undrawn committed facilities not disclosed in the excerpts, underscoring the importance of RCF availability for working capital (2024 AR p.67).
# - The reports reviewed reference liquidity risk within financial risk management, but no covenant definitions, security package details or maturity profile were provided in the excerpts reviewed, so covenant headroom and refinancing timelines are not available (2023 AR p.8).
#
# Sources:
# - Net debt, cash and RCF movement: 2024 AR, Notes, p.67
# - Bankers: 2024 AR, Company Information, p.1
# - EBITDA and results context: 2024 AR, Directors’ Report, p.13
# - Liquidity risk mention: 2023 AR, Strategic Report, p.8
#
# Important notes and data limitations
# - This profile is based on excerpts of the FY2022, FY2023 and FY2024 Radley + Co. Limited annual reports provided. Some disclosures such as detailed segment revenue splits, full cash flow statements, debt terms, covenant packages, employee counts and country-by-country facility listings were not available in the excerpts. If you can share the full reports, especially the Notes covering segmental information, borrowings and cash flow statements, I can complete the missing items and enhance the covenant and liquidity analysis.

# %%
# app.py
import os
import textwrap
from dotenv import load_dotenv, find_dotenv
import json
from rag import (
    retrieve_hybrid_enhanced,
    build_context
)
from typing import List, Dict, Optional
from rag import retrieve_hybrid_enhanced, build_context
from gpts.gpt_assistants import question_to_machine
from openai import OpenAI, APIConnectionError
import streamlit as st

load_dotenv(find_dotenv(), override=True)

# ---- Config (same Azure Search envs you already use) ----
SEARCH_ENDPOINT = os.environ["AZURE_SEARCH_ENDPOINT"]
SEARCH_INDEX    = os.environ["AZURE_SEARCH_INDEX"]
SEARCH_KEY      = os.getenv("AZURE_SEARCH_API_KEY")  # omit if using AAD/RBAC
VECTOR_FIELD    = os.getenv("VECTOR_FIELD")
TEXT_FIELD      = os.getenv("TEXT_FIELD")

# ---- OpenAI (standard) config ----
OPENAI_API_KEY  = os.getenv("FELIPE_OPENAI_API_KEY")        # required
OPENAI_MODEL    = os.getenv("FELIPE_OPENAI_MODEL", "gpt-5")  # e.g., "gpt-5" or "gpt-5-mini"


class WebAgent():

    """
        - This class is responsible to operate calls and allow the usage of websearch
        - The websearch is activated through chat by mentioning "web search" in the paragraph
    """

    def __init__(self,
                k: int = 50,
                max_text_recall_size: int = 200,
                # max_chars: int,
                model: Optional[str] = OPENAI_MODEL,
                top = 20,
                max_output_tokens: int = 1200,
                reasoning_effort: str = "medium",      # "minimal" | "low" | "medium" | "high"
                verbosity: str = "medium",                 # "low" | "medium" | "high"
                tool_choice: str = "none",              # "none" | "auto" | {"type":"tool","name":"..."}
                streaming: bool = False
                ):

        # Parameters settings
        # self.company_name = company_name
        self.k = k
        self.max_text_recall_size = max_text_recall_size
        # self.max_chars = max_chars
        # ===================================
        # RAG PARAMETERS
        self.top = top
        self.k = k
        self.max_text_recall_size

        # ===================================
        # LLM settings
        self.model = model
        # self.temperature = temperature
        # self.top_p = top_p
        self.max_output_tokens = max_output_tokens
        self.reasoning_effort = reasoning_effort
        self.verbosity = verbosity
        self.streaming = streaming

        # OpenAI standard client
        self.web_openai = OpenAI(api_key=OPENAI_API_KEY)

    def _answer(self, question, stream = False):

        # 1. Identify TOOLS call

        # 2. Optimize call
        opt_user_query = question_to_machine(question, OPENAI_API_KEY)

        new_user_query = opt_user_query.output_text

        # 3. Call RAG
        mode, hits = retrieve_hybrid_enhanced(query=new_user_query, top = self.top, k = self.k, max_text_recall_size = self.max_text_recall_size)
        ctx = build_context(hits)
        # 4. Call model

        user_msg = f"Question:\n{new_user_query}\n\nContext snippets (numbered):\n{ctx}"
        system_msg = """"

        You are a restructuring analyst focused on identifying companies in financial distress that could be advisory targets for your company. 
        You prepare comprehensive, accurate and full analysis of companies highlighting liquidity issues, debt maturity risks and covenant pressure. 
        You rely on annual reports and financial statements of companies.

        WHEN the information is NOT FOUND in the context, you USE WEB SEARCH

        **Formatting and Editorial Standards**: 
            - Always **cite sources** 
            - Generate complete profile directly in the chat, take your time and don't compress important things 
            - Always write dates in the format "Mmm-yy" (e.g. Jun-24), fiscal years as "FYXX" (e.g. FY24, LTM1H25), and currencies in millions in the format "£1.2m" 
            - Always double-check revenue split 

        """
        messages = [
            {"role": "system", "content": system_msg},
            {"role": "user",   "content": user_msg},
        ]

        if stream:
            answer_box = st.empty()
            full = ""
            try:
                with self.web_openai.responses.stream(
                    model=self.model,
                    input=messages,
                    tools=[{"type": "web_search"}],
                    tool_choice="auto",
                    # max_output_tokens=self.max_output_tokens,
                    reasoning={"effort": self.reasoning_effort},
                    text={"verbosity": self.verbosity},
                ) as stream:
                    for event in stream:
                        if event.type == "response.output_text.delta":
                            piece = event.delta
                            if piece:
                                full += piece
                                answer_box.markdown(full)
                        elif event.type == "response.error":
                            raise RuntimeError(str(event.error))
                    final = stream.get_final_response()
                    if not full:
                        # fallback to final assembled text if no deltas arrived
                        full = getattr(final, "output_text", "") or ""
                        answer_box.markdown(full)
            except APIConnectionError:
                resp = self.web_openai.responses.create(
                    model=self.model,
                    input=messages,
                    tools=[{"type": "web_search"}],
                    tool_choice="auto",
                    # max_output_tokens=self.max_output_tokens,
                    reasoning={"effort": self.reasoning_effort},
                    text={"verbosity": self.verbosity},
                )
                full = getattr(resp, "output_text", "") or ""
                answer_box.markdown(full)

            return full

        
        resp = self.web_openai.responses.create(
                model=self.model,
                input=messages,
                tools=[{"type": "web_search"}],
                tool_choice="auto",
                # max_output_tokens=self.max_output_tokens,
                reasoning={"effort": self.reasoning_effort},
                text={"verbosity": self.verbosity},
            )
        answer_text = resp.output_text

        return answer_text

# %%
import os, textwrap
from typing import List, Dict, Optional

from dotenv import load_dotenv, find_dotenv
from azure.identity import DefaultAzureCredential
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.models import VectorizableTextQuery
from azure.core.exceptions import HttpResponseError
from azure.search.documents.models import HybridSearch

from openai import AzureOpenAI, APIConnectionError

load_dotenv(find_dotenv(), override=True)

# ---- Config (expects the same envs you already used) ----
SEARCH_ENDPOINT = os.environ["AZURE_SEARCH_ENDPOINT"]
SEARCH_INDEX    = os.environ["AZURE_SEARCH_INDEX"]
SEARCH_KEY      = os.getenv("AZURE_SEARCH_API_KEY")  # omit if using AAD/RBAC
VECTOR_FIELD    = os.getenv("VECTOR_FIELD", "text_vector_v4")
TEXT_FIELD      = os.getenv("TEXT_FIELD", "chunk")

AOAI_ENDPOINT   = os.environ["AZURE_OPENAI_ENDPOINT"]            # https://<resource>.openai.azure.com
AOAI_API_VER    = os.environ.get("AZURE_OPENAI_API_VERSION", "2024-10-21")
AOAI_DEPLOYMENT = os.environ["AZURE_OPENAI_DEPLOYMENT"]          # e.g., gpt-4o-mini / o3-mini / gpt-5 preview
AOAI_KEY        = os.getenv("AZURE_OPENAI_API_KEY")              # omit if using AAD


# AzureOpenAI(azure_endpoint=AOAI_ENDPOINT, api_key=AOAI_KEY, api_version=AOAI_API_VER)

client = AzureOpenAI(azure_endpoint=AOAI_ENDPOINT, api_key=AOAI_KEY, api_version=AOAI_API_VER)
messages = [
    {"role": "user",   "content": 'Tell me company names'},
]

# Try streaming first (SSE). Some networks/proxies block streaming; if so, fall back.
text = ""
stream = client.chat.completions.create(
    model=AOAI_DEPLOYMENT,
    messages=messages,
    stream=True,
    stream_options={"include_usage": True},
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[6], line 38
#      36 # Try streaming first (SSE). Some networks/proxies block streaming; if so, fall back.
#      37 text = ""
# ---> 38 stream = client.chat.completions.create(
#      39     model=AOAI_DEPLOYMENT,
#      40     messages=messages,
#      41     stream=True,
#      42     stream_options={"include_usage": True},
#      43 )
#
# File ~/Documents/GitHub/Azure-OnePager/.venv/lib/python3.9/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Documents/GitHub/Azure-OnePager/.venv/lib/python3.9/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)
#    1144     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~/Documents/GitHub/Azure-OnePager/.venv/lib/python3.9/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/GitHub/Azure-OnePager/.venv/lib/python3.9/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'code': '401', 'message': 'Access denied due to invalid subscription key or wrong API endpoint. Make sure to provide a valid key for an active subscription and use a correct regional API endpoint for your resource.'}}
